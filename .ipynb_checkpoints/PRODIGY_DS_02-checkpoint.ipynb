# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
titanic_data=pd.read_csv("titanic.csv")

# %% [markdown]
# Data description</br>
# Below are the description of the features in the data:</br></br>
#
# Survival: 0 = Did not survive, 1 = Survived</br>
# Pclass: Ticket class where 1 = First class, 2 = Second class, 3 = Third class. This can also be seen as a proxy for socio-economic status.</br>
# Sex: Male or female</br>
# Age: Age in years, fractional if less than 1</br>
# SibSp: Number of siblings or spouses aboard the titanic</br>
# Parch: Number of parents or children aboard the titanic</br>
# Ticket: Passenger ticket number</br>
# Fare: Passenger fare</br>
# Cabin: Cabin number</br>
# Embarked: Point of embarkation where C = Cherbourg, Q = Queenstown, S = Southampton</br>

# %%
titanic_data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
titanic_data.shape
# Out:
# (891, 12)

# %%
titanic_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
titanic_data.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
titanic_data.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
sns.distplot(titanic_data['Age'].dropna(),kde=True)
# Out:
# <Axes: xlabel='Age', ylabel='Density'>

# %%
median=titanic_data['Age'].median()

# %%
titanic_data['Age']=titanic_data['Age'].fillna(median)

# %%
titanic_data.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
titanic_data=titanic_data.dropna(subset=['Embarked'])

# %%
titanic_data.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         0
# dtype: int64

# %%
titanic_data.drop(columns=['Cabin'],axis=1,inplace=True)

# %%
titanic_data.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Embarked       0
# dtype: int64

# %%
titanic_data.shape
# Out:
# (889, 11)

# %%
titanic_data.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   889.000000  889.000000  889.000000  889.000000  889.000000
# mean    446.000000    0.382452    2.311586   29.315152    0.524184
# std     256.998173    0.486260    0.834700   12.984932    1.103705
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     224.000000    0.000000    2.000000   22.000000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.000000    1.000000    3.000000   35.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  889.000000  889.000000
# mean     0.382452   32.096681
# std      0.806761   49.697504
# min      0.000000    0.000000
# 25%      0.000000    7.895800
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
titanic_data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Embarked
# 0      0         A/5 21171   7.2500        S
# 1      0          PC 17599  71.2833        C
# 2      0  STON/O2. 3101282   7.9250        S
# 3      0            113803  53.1000        S
# 4      0            373450   8.0500        S

# %% [markdown]
# # Univariate Analysis

# %% [markdown]
# # On Survived Column

# %%
sns.countplot(titanic_data['Survived'])
# Out:
# <Axes: xlabel='Survived', ylabel='count'>

# %%
death_percent=round((titanic_data['Survived'].value_counts().values[0]/889)*100)
print("Out of 889, percentage of people died in accident is-  {}% ".format(death_percent))
# Out:
# Out of 889, percentage of people died in accident is-  62%

# %% [markdown]
# # On Pclass column

# %%
sns.countplot(titanic_data['Pclass'])
# Out:
# <Axes: xlabel='Pclass', ylabel='count'>

# %%
print((titanic_data['Pclass'].value_counts()/889)*100)
# Out:
# Pclass
# 3    55.230596
# 1    24.071991
# 2    20.697413
# Name: count, dtype: float64

# %% [markdown]
# So 55% of people were travelling through class P3

# %% [markdown]
# # On Sex Column

# %%
sns.countplot(titanic_data['Sex'])
# Out:
# <Axes: xlabel='Sex', ylabel='count'>

# %%
print((titanic_data['Sex'].value_counts()/899)*100)
# Out:
# Sex
# male      64.182425
# female    34.705228
# Name: count, dtype: float64

# %% [markdown]
# So 64% of passengers were male

# %% [markdown]
# # On sibSp Column

# %%
sns.countplot(titanic_data['SibSp'])
# Out:
# <Axes: xlabel='SibSp', ylabel='count'>

# %%
print((titanic_data['SibSp'].value_counts()/899)*100)
# Out:
# SibSp
# 0    67.408231
# 1    23.248053
# 2     3.114572
# 4     2.002225
# 3     1.779755
# 8     0.778643
# 5     0.556174
# Name: count, dtype: float64

# %% [markdown]
# So 67% of people were travelling individually

# %% [markdown]
# # On Parch column

# %%
sns.countplot(titanic_data['Parch'])
# Out:
# <Axes: xlabel='Parch', ylabel='count'>

# %% [markdown]
# # On embarked Column

# %%
sns.countplot(titanic_data['Embarked'])
# Out:
# <Axes: xlabel='Embarked', ylabel='count'>

# %%
print((titanic_data['Embarked'].value_counts()/899)*100)
# Out:
# Embarked
# S    71.635150
# C    18.687430
# Q     8.565072
# Name: count, dtype: float64

# %% [markdown]
# so 71% of people's embarked point was -Southampton

# %%
int_col=titanic_data.select_dtypes(include=['int64']).columns.tolist()
int_col
# Out:
# ['PassengerId', 'Survived', 'Pclass', 'SibSp', 'Parch']

# %%
object_col=titanic_data.select_dtypes(include=['float']).columns.tolist()
object_col
# Out:
# ['Age', 'Fare']

# %%
float_col=titanic_data.select_dtypes(include=["float64"]).columns.tolist()
float_col
# Out:
# ['Age', 'Fare']

# %%
sns.distplot(titanic_data['Age'],kde=True)
# Out:
# <Axes: xlabel='Age', ylabel='Density'>

# %%
print(titanic_data['Age'].skew())
print(titanic_data['Age'].kurt())
# Out:
# 0.5080100783148638
# 1.0078198132258307

# %%
sns.boxplot(titanic_data['Age'])
# Out:
# <Axes: xlabel='Age'>

# %%
sns.distplot(titanic_data['Fare'],kde=True)
# Out:
# <Axes: xlabel='Fare', ylabel='Density'>

# %%
print(titanic_data['Fare'].skew())
print(titanic_data['Fare'].kurt())
# Out:
# 4.801440211044194
# 33.508477269700144

# %%
sns.boxplot(titanic_data['Fare'])
# Out:
# <Axes: xlabel='Fare'>

# %%
pd.crosstab(titanic_data['Pclass'],titanic_data['Survived']).apply(lambda r: round((r/r.sum())*100,1),axis=1)
# Out:
# Survived     0     1
# Pclass
# 1         37.4  62.6
# 2         52.7  47.3
# 3         75.8  24.2

# %% [markdown]
# # Multivariate Analysis

# %%
#survived with Pclass

sns.countplot(titanic_data['Survived'],hue=titanic_data['Pclass'])
# Out:
# <Axes: xlabel='Survived', ylabel='count'>

# %% [markdown]
# More P3 class people were not able to survived

# %%
#survived with Sex

sns.countplot(titanic_data['Survived'],hue=titanic_data['Sex'])
# Out:
# <Axes: xlabel='Survived', ylabel='count'>

# %% [markdown]
# More number of survivals were female

# %%
#survived with Embarked

sns.countplot(titanic_data['Survived'],hue=titanic_data['Embarked'])
# Out:
# <Axes: xlabel='Survived', ylabel='count'>

# %%
pd.crosstab(titanic_data['Embarked'],titanic_data['Survived']).apply(lambda r: round((r/r.sum())*100,1),axis=1)
# Out:
# Survived     0     1
# Embarked
# C         44.6  55.4
# Q         61.0  39.0
# S         66.3  33.7

# %%
#Surviced with Age

plt.figure(figsize=(10,7))
sns.distplot(titanic_data[titanic_data['Survived']==0]['Age'],kde=True,color='red')
sns.distplot(titanic_data[titanic_data['Survived']==1]['Age'],kde=True,color='green')
# Out:
# <Axes: xlabel='Age', ylabel='Density'>

# %%
#Survived with Fare

plt.figure(figsize=(10,7))
sns.distplot(titanic_data[titanic_data['Survived']==0]['Fare'],kde=True,color='red')
sns.distplot(titanic_data[titanic_data['Survived']==1]['Fare'],kde=True,color='green')
# Out:
# <Axes: xlabel='Fare', ylabel='Density'>

# %%
sns.pairplot(titanic_data)

# %%
sns.heatmap(titanic_data[['PassengerId','Pclass','Survived', 'SibSp', 'Parch', 'Age', 'Fare']].corr())
# Out:
# <Axes: >

# %%
plt.figure(figsize=(10, 6))
titanic_data.boxplot()
# Out:
# <Axes: >

# %% [markdown]
# # Removing Outliers

# %%
#Handling outliers from Age column

titanic_data=titanic_data[titanic_data['Age']<(titanic_data['Age'].mean() + 3 * titanic_data['Age'].std())]
titanic_data.shape
# Out:
# (882, 11)

# %%
#Handling outliers from Fare column

Q1=np.percentile(titanic_data['Fare'],25)
Q3=np.percentile(titanic_data['Fare'],75)

outlier_low=Q1 - 1.5 * (Q3-Q1)
outlier_high=Q3 +1.5 * (Q3-Q1)

titanic_data=titanic_data[(titanic_data['Fare']>outlier_low) & (titanic_data['Fare']<outlier_high)]

# %%
titanic_data.shape
# Out:
# (767, 11)

# %%
titanic_data=pd.get_dummies(data=titanic_data, columns=['Pclass','Sex','Embarked'],drop_first=True)

# %%
titanic_data.head()
# Out:
#    PassengerId  Survived                                          Name   Age  \
# 0            1         0                       Braund, Mr. Owen Harris  22.0
# 2            3         1                        Heikkinen, Miss. Laina  26.0
# 3            4         1  Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0
# 4            5         0                      Allen, Mr. William Henry  35.0
# 5            6         0                              Moran, Mr. James  28.0
#
#    SibSp  Parch            Ticket     Fare  Pclass_2  Pclass_3  Sex_male  \
# 0      1      0         A/5 21171   7.2500     False      True      True
# 2      0      0  STON/O2. 3101282   7.9250     False      True     False
# 3      1      0            113803  53.1000     False     False     False
# 4      0      0            373450   8.0500     False      True      True
# 5      0      0            330877   8.4583     False      True      True
#
#    Embarked_Q  Embarked_S
# 0       False        True
# ...

# %%
titanic_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 767 entries, 0 to 890
# Data columns (total 13 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  767 non-null    int64
#  1   Survived     767 non-null    int64
#  2   Name         767 non-null    object
#  3   Age          767 non-null    float64
#  4   SibSp        767 non-null    int64
#  5   Parch        767 non-null    int64
#  6   Ticket       767 non-null    object
#  7   Fare         767 non-null    float64
#  8   Pclass_2     767 non-null    bool
#  9   Pclass_3     767 non-null    bool
#  10  Sex_male     767 non-null    bool
#  11  Embarked_Q   767 non-null    bool
#  12  Embarked_S   767 non-null    bool
# dtypes: bool(5), float64(2), int64(4), object(2)
# memory usage: 57.7+ KB

# %%
titanic_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 767 entries, 0 to 890
# Data columns (total 13 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  767 non-null    int64
#  1   Survived     767 non-null    int64
#  2   Name         767 non-null    object
#  3   Age          767 non-null    float64
#  4   SibSp        767 non-null    int64
#  5   Parch        767 non-null    int64
#  6   Ticket       767 non-null    object
#  7   Fare         767 non-null    float64
#  8   Pclass_2     767 non-null    bool
#  9   Pclass_3     767 non-null    bool
#  10  Sex_male     767 non-null    bool
#  11  Embarked_Q   767 non-null    bool
#  12  Embarked_S   767 non-null    bool
# dtypes: bool(5), float64(2), int64(4), object(2)
# memory usage: 57.7+ KB

# %%
plt.figure(figsize=(20,10))
sns.heatmap(titanic_data[['PassengerId','Pclass_2','Pclass_3','Survived','Sex_male','Embarked_Q', 'Embarked_S','SibSp', 'Parch', 'Age', 'Fare']].corr(),annot=True)
# Out:
# <Axes: >

# %% [markdown]
# # Conclusions

# %% [markdown]
# Chances of Female Survival is more than Male survival</br>
# Travelling in Pclass 3 means more chances of not getting survived</br>
# People with Embarked C survived more</br>
# People in Age range of 20 to 40 had lower chances of survival
